# %% [markdown]
# # CS146 Final Project: Modeling and forecasting atmospheric CO₂ from 1958 into the future

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd

# %%
data_co2 = pd.read_csv('weekly_in_situ_co2_mlo.csv', skiprows=44, names=['date', 'co2 ppm'])
data_co2.head()
# Out:
#          date  co2 ppm
# 0  1958-03-29   316.19
# 1  1958-04-05   317.31
# 2  1958-04-12   317.69
# 3  1958-04-19   317.58
# 4  1958-04-26   316.48

# %% [markdown]
# #### Converting dates

# %% [markdown]
# Let's convert dates so that they can be plotted as x-axis values, starting from 0.

# %%
data_co2['date']=pd.to_datetime(data_co2['date'])
start = data_co2['date'][0]
data_co2['datetime'] = data_co2['date'] - start
data_co2['date_num'] = data_co2['datetime'].dt.days

# %%
data_co2.head()
# Out:
#         date  co2 ppm datetime  date_num
# 0 1958-03-29   316.19   0 days         0
# 1 1958-04-05   317.31   7 days         7
# 2 1958-04-12   317.69  14 days        14
# 3 1958-04-19   317.58  21 days        21
# 4 1958-04-26   316.48  28 days        28

# %%
data_co2.tail()
# Out:
#            date  co2 ppm   datetime  date_num
# 3237 2021-08-28   412.68 23163 days     23163
# 3238 2021-09-04   412.58 23170 days     23170
# 3239 2021-09-11   413.15 23177 days     23177
# 3240 2021-09-18   413.09 23184 days     23184
# 3241 2021-09-25   413.05 23191 days     23191

# %% [markdown]
# ## Plotting data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(data_co2['date_num'], data_co2.iloc[:,1], color='maroon')
plt.ylabel('CO2 Level (ppm)', size=10)
plt.xlabel('Day', size=10)
plt.title("Carbon dioxide levels in the atmosphere (ppm) \n Mauna Loa, 1958-2021")
plt.show()

# %% [markdown]
# #### Using a function from class sessions to plot autocorrelation.

# %%
# plotting sample autocorrelation for every parameter
def plot_acf(x):
    '''
    Plot the autocorrelation function for a series x. This corresponds to the
    acf() function in R. The series x is detrended by subtracting the mean of
    the series before computing the autocorrelation.
    '''
    from scipy import signal    
    plt.acorr(
        x, maxlags=20, detrend=lambda x: signal.detrend(x, type='constant'))

# %%
# displaying the autocorrelation plots
def acf_plots(posterior_samples, parameters):
    plt.figure(figsize=(15, 17))
    for x in range(len(parameters)):
        plt.subplot(4,3,x + 1)
        plot_acf(posterior_samples[parameters[x]])
        plt.title(f'Autocorrelation of {parameters[x]} samples')
    plt.show()

# %%
# plotting pair plot of the posteriors over all parameters
def pair_plots(posterior_samples, parameters):
    df = pd.DataFrame(
        data=np.transpose([posterior_samples[x] for x in parameters]),
        columns=parameters)
    sns.pairplot(df, size=2.5, plot_kws={'marker': '.', 'alpha': 0.25})
    plt.show()

# %%
import pystan
import numpy as np
import scipy.stats as sts

# %% [markdown]
# ## Linear Model

# %%
# input data
stan_data = {'N': len(data_co2['date_num']), 
            'co2': data_co2['co2 ppm'],
            'day': data_co2['date_num']}

# %%
# create the stan model

stan_code_linear_model = """

data {
    // model data
    int<lower=0> N;        //size of the data observations
    real<lower=0> co2[N];  //an observation of CO2 level
    real<lower=0> day[N];  // day of observation collection
}

parameters {
    // model parameters
    real<lower=0> c0;   // intercept parameter
    real<lower=0> c1;   // slope value parameter
    real<lower=0> c2; // seasonal variation parameter (multiplicator)
    real<lower=0, upper=1> c3;  // day variation parameter (added to annual number of days)    
    real<lower=0> sigma;        // noise parameter         
}


model {
    //priors 
    c0 ~ normal(300, 15); // prior based on the values of CO2 level at the start
    c1 ~ cauchy(0, 1); // slope (time) parameter prior
    c2 ~ cauchy(0, 1); // slope (seasonal variation) parameter prior
    c3 ~ cauchy(0, 1); // day (seasonal variation) parameter prior
    sigma ~ lognormal(0, 1); // prior for standard deviation^2 (variance)

    //likelihood
    for (observation in 1:N) {
      co2[observation] ~ normal(c0+c1*day[observation]+c2*cos(2*pi()*day[observation]/(365.25+c3)), sigma);
    }

}
"""

# %%
# make the model
stan_model_linear = pystan.StanModel(model_code=stan_code_linear_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_dc5584be48492c456cbf3a8f78d8742d NOW.

# %%
# fitting stan model to the data. 
# generating samples from the posterior over all parameters
stan_results_linear_model = stan_model_linear.sampling(data=stan_data)
print(stan_results_linear_model)
# Out:
# Inference for Stan model: anon_model_dc5584be48492c456cbf3a8f78d8742d.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# c0    305.45  2.2e-3   0.14 305.17 305.36 305.45 305.55 305.73   4132    1.0
# c1    4.4e-3  1.6e-7 1.1e-5 4.4e-3 4.4e-3 4.4e-3 4.4e-3 4.4e-3   4329    1.0
# c2      2.82  2.1e-3    0.1   2.62   2.76   2.83   2.89   3.02   2326    1.0
# c3      0.56  1.1e-3   0.06   0.45   0.52   0.56    0.6   0.67   2430    1.0
# sigma   4.11  1.1e-3   0.05    4.0   4.07   4.11   4.14   4.21   2429    1.0
# lp__   -6205    0.04    1.6  -6209  -6205  -6204  -6203  -6202   1596    1.0
#
# Samples were drawn using NUTS at Wed Dec 15 23:58:32 2021.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# extracting the generated samples from the Stan model
samples_linear_model = stan_results_linear_model.extract()

# %%
# putting all parameters in a list
parameter_linear_model = ['c0', 'c1', 'c2','c3','sigma']
# creating autocorrelation plots
acf_plots(samples_linear_model, parameter_linear_model)

# %%
# creating pair plots
pair_plots(samples_linear_model, parameter_linear_model)
# Out:
# /Users/andriykashyrskyy/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
linear_model_co2 = np.array(sts.norm.rvs(np.mean(samples_linear_model['c0'])+ np.mean(samples_linear_model['c1'])*data_co2.iloc[:,3]+np.mean(samples_linear_model['c2'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.mean(samples_linear_model['c3'])), np.mean(samples_linear_model['sigma'])))
plt.plot(data_co2.iloc[:,3], linear_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label="Observed Data")
plt.legend(prop={'size':10})
plt.show()

# %%
## zooming in on the original plot
## zooming in on the original plot
plt.plot(data_co2.iloc[:,3], linear_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label="Observed Data")
plt.legend(prop={'size':8})
plt.axis([22000, 23000, 390, 420])
plt.show()

# %% [markdown]
# ## Quadratic Model

# %%
#Build the stan model
stan_code_quadratic_model = """

data {
    // model data
    int<lower=0> N;        //size of the data observations
    real<lower=0> co2[N];  //an observation of CO2 level
    real<lower=0> day[N];  // day of observation collection
}

parameters {
    // model parameters
    real<lower=0> c0;   // intercept parameter
    real<lower=0> c1;   // slope value parameter
    real<lower=0> c2; // seasonal variation parameter (multiplicator)
    real<lower=0, upper=1> c3;  // day variation parameter (added to annual number of days)    
    real<lower=0> sigma;        // noise parameter         
}


model {
    //priors 
    c0 ~ normal(300, 15); // prior based on the values of CO2 level at the start
    c1 ~ cauchy(0, 1); // slope (time) parameter prior
    c2 ~ cauchy(0, 1); // slope (seasonal variation) parameter prior
    c3 ~ cauchy(0, 1); // day (seasonal variation) parameter prior
    sigma ~ lognormal(0, 1); // prior for standard deviation^2 (variance)

    //likelihood
    for (observation in 1:N) {
      co2[observation] ~ normal(c0+c1*(day[observation]^2)+c2*cos(2*pi()*day[observation]/(365.25+c3)), sigma);
    }

}
"""

# %%
# compile the model
stan_model_quadratic = pystan.StanModel(model_code=stan_code_quadratic_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_a24f199503ffc839d3dfa59b868c90c1 NOW.

# %%
# fitting stan model to the data
# this will generate samples from the posterior over all parameters of the model.
stan_results_quadratic = stan_model_quadratic.sampling(data=stan_data)
print(stan_results_quadratic)
# Out:
# Inference for Stan model: anon_model_a24f199503ffc839d3dfa59b868c90c1.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# c0    323.86  1.5e-3    0.1 323.68  323.8 323.86 323.93 324.05   4361    1.0
# c1    1.8e-7 6.9e-124.0e-10 1.8e-7 1.8e-7 1.8e-7 1.8e-7 1.8e-7   3378    1.0
# c2      2.77  1.8e-3   0.09   2.59   2.71   2.77   2.83   2.94   2641    1.0
# c3       0.5  9.6e-4   0.05   0.41   0.47    0.5   0.54   0.59   2505    1.0
# sigma   3.54  9.3e-4   0.04   3.46   3.51   3.54   3.57   3.63   2290    1.0
# lp__   -5733    0.04   1.62  -5737  -5734  -5733  -5732  -5731   1588    1.0
#
# Samples were drawn using NUTS at Thu Dec 16 00:00:30 2021.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# Extract the generated samples from the stan model
samples_quadratic_model = stan_results_quadratic.extract()

# %%
#autocorrelation plots
quadratic_parameters = ['c0', 'c1', 'c2', 'c3', 'sigma']
acf_plots(samples_quadratic_model, quadratic_parameters)

# %%
#pair plots
pair_plots(samples_quadratic_model, quadratic_parameters)
# Out:
# /Users/andriykashyrskyy/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
quadratic_model_co2 = np.array(sts.norm.rvs(np.mean(samples_quadratic_model['c0'])+ np.mean(samples_quadratic_model['c1'])*(data_co2.iloc[:,3]**2)+np.mean(samples_quadratic_model['c2'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.mean(samples_quadratic_model['c3'])), np.mean(samples_quadratic_model['sigma'])))
plt.plot(data_co2.iloc[:,3], quadratic_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label='Observed Data')
plt.legend(prop={'size':10})
plt.show()

# %%
## zooming in on the original plot
plt.plot(data_co2.iloc[:,3], quadratic_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label='Observed Data')
plt.axis([22000, 23000, 400, 430])
plt.legend(prop={'size':10})
plt.show()

# %% [markdown]
# ## Linear-Quadratic Model

# %%
#Build the stan model
stan_code_linear_quad_model = """

data {
    // model data
    int<lower=0> N;        //size of the data observations
    real<lower=0> co2[N];  //an observation of CO2 level
    real<lower=0> day[N];  // day of observation collection
}

parameters {
    // model parameters
    real<lower=0> c0;   // intercept parameter
    real<lower=0> c1;   // slope value parameter
    real<lower=0> c2; // seasonal variation parameter (multiplicator)
    real<lower=0> c3; // seasonal variation parameter (multiplicator), for quadratic expression
    real<lower=0, upper=1> c4;  // day variation parameter (added to annual number of days)  
    real<lower=0> sigma;        // noise parameter         
}


model {
    //priors 
    c0 ~ normal(300, 15); // prior based on the values of CO2 level at the start
    c1 ~ cauchy(0, 1); // slope (time) parameter prior, for linear
    c2 ~ cauchy(0, 1); // slope (time) parameter prior, for quadratic
    c3 ~ cauchy(0, 1); // slope (seasonal variation) parameter prior
    c4 ~ cauchy(0, 1); // samples_linear_quad_model
    sigma ~ lognormal(0, 1); // prior for standard deviation^2 (variance)

    //likelihood
    for (observation in 1:N) {
      co2[observation] ~ normal(c0+c1*(day[observation])+c2*(day[observation]^2)+c3*cos(2*pi()*day[observation]/(365.25+c4)), sigma);
    }

}
"""

# %%
# compile the model
stan_model_linear_quad = pystan.StanModel(model_code=stan_code_linear_quad_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_129d72dbf1bcf809560f2de807469363 NOW.

# %%
# fitting stan model to the data
# this will generate samples from the posterior over all parameters of the model.
stan_results_linear_quad = stan_model_linear_quad.sampling(data=stan_data)
print(stan_results_linear_quad)
# Out:
# Inference for Stan model: anon_model_129d72dbf1bcf809560f2de807469363.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# c0    314.74  1.2e-3   0.06 314.62  314.7 314.74 314.78 314.86   2335    1.0
# c1    2.1e-3  2.6e-7 1.2e-5 2.0e-3 2.0e-3 2.1e-3 2.1e-3 2.1e-3   1949    1.0
# c2   10.0e-8 1.1e-114.8e-10 9.9e-8 9.9e-810.0e-8 1.0e-7 1.0e-7   1939   1.01
# c3       2.8  5.2e-4   0.03   2.74   2.78    2.8   2.81   2.85   2611    1.0
# c4      0.53  2.7e-4   0.01    0.5   0.52   0.53   0.54   0.56   2982    1.0
# sigma   1.09  2.6e-4   0.01   1.06   1.08   1.09    1.1   1.12   2835    1.0
# lp__   -1915    0.04   1.73  -1919  -1916  -1914  -1914  -1912   1613    1.0
#
# Samples were drawn using NUTS at Thu Dec 16 00:04:40 2021.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# Extract the generated samples from the stan model
samples_linear_quad_model = stan_results_linear_quad.extract()

# %%
#autocorrelation plots
linear_quad_parameters = ['c0', 'c1', 'c2', 'c3', 'c4', 'sigma']
acf_plots(samples_linear_quad_model, linear_quad_parameters)

# %%
#pair plots
pair_plots(samples_linear_quad_model, linear_quad_parameters)
# Out:
# /Users/andriykashyrskyy/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
linear_quadratic_model_co2 = np.array(sts.norm.rvs(np.mean(samples_linear_quad_model['c0']) + np.mean(samples_linear_quad_model['c1'])*(data_co2.iloc[:,3]) + np.mean(samples_linear_quad_model['c2'])*(data_co2.iloc[:,3]**2)+np.mean(samples_linear_quad_model['c3'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.mean(samples_linear_quad_model['c4'])), np.mean(samples_linear_quad_model['sigma'])))
plt.plot(data_co2.iloc[:,3], linear_quadratic_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label='Observed Data')
plt.legend(prop={'size':10})
plt.show()

# %%
## zooming in on the original plot
plt.plot(data_co2.iloc[:,3], linear_quadratic_model_co2, color='royalblue', label='Modeled Data')
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon', label='Observed Data')
plt.legend(prop={'size':10})
plt.xlabel('Day', size = 10)
plt.ylabel('Carbon Dioxide (CO2) ppm', size=10)
plt.title('Observed CO2 levels, and modeled CO2 levels (1958 to 2021)', size=11)
plt.axis([22000, 23000, 400, 430])
plt.show()

# %% [markdown]
# ## Using test statistics for assessing the model

# %%
def test_statistic(data, stat_name):
    statistics = {'mean': np.mean,
                  'std': np.std,
                  'minimum': np.min,
                  'maximum': np.max}
    
    return statistics[stat_name](data)

# %% [markdown]
# ### Linear Model

# %%
linear_data_replicated = []

mean_linear = []
std_linear = []
min_linear = []
max_linear = []

for i in range(1500):
    linear_data_replicated.append(np.array(sts.norm.rvs(np.random.choice(samples_linear_model['c0'])+ np.random.choice(samples_linear_model['c1'])*data_co2.iloc[:,3]+np.random.choice(samples_linear_model['c2'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.random.choice(samples_linear_model['c3'])), np.random.choice(samples_linear_model['sigma']))))
    mean_linear.append(test_statistic(linear_data_replicated[-1], 'mean'))
    std_linear.append(test_statistic(linear_data_replicated[-1], 'std'))
    min_linear.append(test_statistic(linear_data_replicated[-1], 'minimum'))
    max_linear.append(test_statistic(linear_data_replicated[-1], 'maximum'))

# %% [markdown]
# #### Plotting test statistics for Linear Model

# %%
# mean
plt.hist(mean_linear, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'mean'), color="maroon")
plt.title('Linear Model: Distribution of mean in replicated samples')
plt.show()

p_value = sum([1 for i in mean_linear if i > test_statistic(list(data_co2.iloc[:,1]), 'mean')])/1500
print("P-value:", round(p_value, 3))

# standard deviation
plt.hist(std_linear, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'std'), color="maroon")
plt.title('Linear Model: Distribution of standard deviation in replicated samples')
plt.show()

p_value = sum([1 for i in std_linear if i > test_statistic(list(data_co2.iloc[:,1]), 'std')])/1500
print("P-value:", round(p_value, 3))

# minimum
plt.hist(min_linear, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'minimum'), color="maroon")
plt.title('Linear Model: Distribution of minimum in replicated samples')
plt.show()

p_value = sum([1 for i in min_linear if i > test_statistic(list(data_co2.iloc[:,1]), 'minimum')])/1500
print("P-value:", round(p_value, 3))

# maximum
plt.hist(max_linear, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'maximum'), color="maroon")
plt.title('Linear Model: Distribution of maximum in replicated samples')
plt.show()

p_value = sum([1 for i in max_linear if i > test_statistic(list(data_co2.iloc[:,1]), 'maximum')])/1500
print("P-value:", round(p_value, 3))
# Out:
# P-value: 0.483
# P-value: 0.431
# P-value: 0.0
# P-value: 0.105

# %% [markdown]
# ### Quadratic model

# %%
quadratic_data_replicated = []

mean_quadratic = []
std_quadratic = []
min_quadratic = []
max_quadratic = []

for i in range(1500):
    quadratic_data_replicated.append(np.array(sts.norm.rvs(np.random.choice(samples_quadratic_model['c0'])+ np.random.choice(samples_quadratic_model['c1'])*(data_co2.iloc[:,3]**2)+np.random.choice(samples_quadratic_model['c2'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.random.choice(samples_quadratic_model['c3'])), np.random.choice(samples_quadratic_model['sigma']))))
    mean_quadratic.append(test_statistic(quadratic_data_replicated[-1], 'mean'))
    std_quadratic.append(test_statistic(quadratic_data_replicated[-1], 'std'))
    min_quadratic.append(test_statistic(quadratic_data_replicated[-1], 'minimum'))
    max_quadratic.append(test_statistic(quadratic_data_replicated[-1], 'maximum'))

# %% [markdown]
# #### Plotting test statistics for Quadratic model

# %%
# mean
plt.hist(mean_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'mean'), color="maroon")
plt.title('Quadratic Model: Distribution of mean in replicated samples')
plt.show()
p_value = sum([1 for i in mean_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'mean')])/1500
print("P-value:", round(p_value, 3))

# standard deviation
plt.hist(std_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'std'), color="maroon")
plt.title('Quadratic Model: Distribution of standard deviation in replicated samples')
plt.show()
p_value = sum([1 for i in std_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'std')])/1500
print("P-value:", round(p_value, 3))

# minimum
plt.hist(min_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'minimum'), color="maroon")
plt.title('Quadratic Model: Distribution of minimum in replicated samples')
plt.show()
p_value = sum([1 for i in min_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'minimum')])/1500
print("P-value:", round(p_value, 3))

# maximum
plt.hist(max_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'maximum'), color="maroon")
plt.title('Quadratic Model: Distribution of maximum in replicated samples')
plt.show()
p_value = sum([1 for i in max_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'maximum')])/1500
print("P-value:", round(p_value, 3))
# Out:
# P-value: 0.475
# P-value: 0.409
# P-value: 0.39
# P-value: 1.0

# %% [markdown]
# ### Linear-Quadratic model

# %%
linear_quadratic_data_replicated = []

mean_linear_quadratic = []
std_linear_quadratic = []
min_linear_quadratic = []
max_linear_quadratic = []

for i in range(1500):
    linear_quadratic_data_replicated.append(np.array(sts.norm.rvs(np.random.choice(samples_linear_quad_model['c0'])+ np.random.choice(samples_linear_quad_model['c1'])*(data_co2.iloc[:,3])+np.random.choice(samples_linear_quad_model['c2'])*(data_co2.iloc[:,3]**2)+np.random.choice(samples_linear_quad_model['c3'])*np.cos((2*np.pi*data_co2.iloc[:,3])/365.25+np.random.choice(samples_linear_quad_model['c4'])), np.random.choice(samples_linear_quad_model['sigma']))))
    mean_linear_quadratic.append(test_statistic(linear_quadratic_data_replicated[-1], 'mean'))
    std_linear_quadratic.append(test_statistic(linear_quadratic_data_replicated[-1], 'std'))
    min_linear_quadratic.append(test_statistic(linear_quadratic_data_replicated[-1], 'minimum'))
    max_linear_quadratic.append(test_statistic(linear_quadratic_data_replicated[-1], 'maximum'))

# %% [markdown]
# #### Plotting test statistics for Linear-Quadratic model

# %%
# mean
plt.hist(mean_linear_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'mean'), color="maroon", label='True mean')
plt.title('Linear-Quadratic Model: Distribution of mean in replicated samples')
plt.show()
p_value = sum([1 for i in mean_linear_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'mean')])/1500
print("P-value:", round(p_value, 3))

# standard deviation
plt.hist(std_linear_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'std'), color="maroon", label='True standard deviation')
plt.title('Linear-Quadratic Model: Distribution of standard deviation in replicated samples')
plt.show()
p_value = sum([1 for i in std_linear_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'std')])/1500
print("P-value:", round(p_value, 3))

# minimum
plt.hist(min_linear_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'minimum'), color="maroon", label='True minimum')
plt.title('Linear-Quadratic Model: Distribution of minimum in replicated samples')
plt.show()
p_value = sum([1 for i in min_linear_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'minimum')])/1500
print("P-value:", round(p_value, 3))

# maximum
plt.hist(max_linear_quadratic, color = "royalblue")
plt.axvline(test_statistic(list(data_co2.iloc[:,1]), 'maximum'), color="maroon", label='True maximum')
plt.title('Linear-Quadratic Model: Distribution of maximum in replicated samples')
plt.show()
p_value = sum([1 for i in max_linear_quadratic if i > test_statistic(list(data_co2.iloc[:,1]), 'maximum')])/1500
print("P-value:", round(p_value, 3))
# Out:
# P-value: 0.472
# P-value: 0.415
# P-value: 0.0
# P-value: 0.162

# %% [markdown]
# ## Linear-Quadratic Model plotted against all dataset

# %%
plt.figure(figsize = (20,12))

plt.plot(data_co2.iloc[:,3], linear_quadratic_model_co2, color='royalblue', label = "Modeled CO2 levels")
plt.plot(data_co2.iloc[:,3], data_co2.iloc[:,1], color='maroon',  label = "Observed CO2 levels")

plt.xlabel('Day', size = 20)
plt.ylabel('Carbon Dioxide (CO2) ppm', size=20)
plt.legend(prop={'size':20})
plt.title('Observed CO2 levels, and modeled CO2 levels (1958 to 2021)', size=22)

plt.show()

# %% [markdown]
# ## Predicting the CO2 levels in the future

# %%
N_future = int(39*365.25) + 23191
N_future_range = np.array(range(23191, N_future, 7))

def linear_quad_model_pred(posterior_samples, day_range, func, args=0):
    return np.array(sts.norm.rvs(func(posterior_samples['c0'], args) + func(posterior_samples['c1'], args)*(N_future_range)+func(posterior_samples['c2'], args)*((N_future_range)*(N_future_range))+ func(posterior_samples['c3'], args)*np.cos((2*np.pi*N_future_range)/365.25 + func(posterior_samples['c4'], args)), func(posterior_samples['sigma'], args)))

linear_quad_predicted = linear_quad_model_pred(samples_linear_quad_model, N_future_range, np.mean)

# %%
lower_ci = linear_quad_model_pred(samples_linear_quad_model, N_future_range, np.percentile, 2.5)
upper_ci = linear_quad_model_pred(samples_linear_quad_model, N_future_range, np.percentile, 97.5)

# %%
plt.figure(figsize = (20, 12))

# plotting Observed and Unobserved data
plt.plot(data_co2['date_num'], data_co2['co2 ppm'], label = 'Observed Data', color='maroon')
plt.plot(N_future_range, linear_quad_predicted, color='royalblue', label="Unobserved Data")

# plotting Confidence Intervals
plt.plot(N_future_range, lower_ci, color="crimson", linewidth = 0.5)
plt.plot(N_future_range, upper_ci, color="crimson", linewidth = 0.5, label = "Predicted 95% Confidence Interval")

#plotting a line of the most recent observed CO2 level, from which prediction starts
plt.axhline(450, color='orangered', label = 'High Risk Level (450 CO2 ppm)')
plt.axvline(N_future_range[0], color='olivedrab', label = "Starting Time of Prediction")

plt.xlabel('Day', size = 20)
plt.ylabel('Carbon Dioxide (CO2) ppm', size=20)
plt.legend(prop={'size':20})
plt.title("Observed CO2 levels, and predicted (unobserved) CO2 levels until 2060, with 95% CI", fontsize=22)

plt.show()

# %%
plt.figure(figsize = (20, 12))

# plotting Unobserved (Predicted) data
plt.plot(N_future_range[0:700], linear_quad_predicted[0:700], color='royalblue', label="Unobserved Data")

# plotting Confidence Intervals
plt.plot(N_future_range[0:700], lower_ci[0:700], color="crimson", linewidth = 0.5)
plt.plot(N_future_range[0:700], upper_ci[0:700], color="crimson", linewidth = 0.5, label = "Predicted 95% Confidence Interval")

#plotting a line of the most recent observed CO2 level, from which prediction starts
plt.axhline(450, color='orangered', label = 'High Risk Level (450 CO2 ppm)')

plt.xlabel('Day', size = 20)
plt.ylabel('Carbon Dioxide (CO2) ppm', size=20)
plt.legend(prop={'size':20})
plt.title('Unobserved predicted levels of CO2 and their predicted 95% Confidence Inteval', fontsize=22)

plt.show()

# %%
plt.figure(figsize = (20, 12))

# plotting Unobserved (Predicted) data
plt.plot(N_future_range[500:900], linear_quad_predicted[500:900], color='royalblue', label="Unobserved Data")

# plotting Confidence Intervals
plt.plot(N_future_range[500:900], lower_ci[500:900], color="crimson", linewidth = 0.5)
plt.plot(N_future_range[500:900], upper_ci[500:900], color="crimson", linewidth = 0.5, label = "Predicted 95% Confidence Interval")

#plotting a line of the most recent observed CO2 level, from which prediction starts
plt.axhline(450, color='orangered', label = 'High Risk Level (450 CO2 ppm)')

plt.xlabel('Day', size = 20)
plt.ylabel('Carbon Dioxide (CO2) ppm', size=20)
plt.legend(prop={'size':20})
plt.title('Unobserved predicted levels of CO2 and their predicted 95% Confidence Inteval', fontsize=22)

plt.show()

# %%
data_co2_predicted = pd.DataFrame(data={"Day": N_future_range, "mean_co2": linear_quad_predicted, 'lower_95_ci':lower_ci, 'upper_95_ci': upper_ci})
data_co2_predicted.head()
# Out:
#      Day    mean_co2  lower_95_ci  upper_95_ci
# 0  23191  414.267761   414.602610   413.381979
# 1  23198  412.962671   410.800522   415.806776
# 2  23205  414.877706   413.458401   415.745756
# 3  23212  414.578136   413.672010   415.163811
# 4  23219  415.634766   414.231569   415.883969

# %%
dates_range = pd.date_range('2021-09-27', periods=len(data_co2_predicted), freq='W')
data_co2_predicted['date'] = dates_range
data_co2_predicted
# Out:
#         Day    mean_co2  lower_95_ci  upper_95_ci       date
# 0     23191  414.267761   414.602610   413.381979 2021-10-03
# 1     23198  412.962671   410.800522   415.806776 2021-10-10
# 2     23205  414.877706   413.458401   415.745756 2021-10-17
# 3     23212  414.578136   413.672010   415.163811 2021-10-24
# 4     23219  415.634766   414.231569   415.883969 2021-10-31
# ...     ...         ...          ...          ...        ...
# 2030  37401  527.495413   526.080565   530.684738 2060-08-29
# 2031  37408  527.354603   525.581546   530.286316 2060-09-05
# 2032  37415  526.422205   525.141688   531.063439 2060-09-12
# 2033  37422  528.191341   527.380714   531.116679 2060-09-19
# 2034  37429  527.131776   526.156048   532.806804 2060-09-26
#
# [2035 rows x 5 columns]

# %%
high_risk_mean = data_co2_predicted['date'][data_co2_predicted['mean_co2'] >= 450].iloc[0].strftime('%B %d, %Y')
high_risk_lower_ci = data_co2_predicted['date'][data_co2_predicted['lower_95_ci'] >= 450].iloc[0].strftime('%B %d, %Y')
high_risk_upper_ci = data_co2_predicted['date'][data_co2_predicted['upper_95_ci'] >= 450].iloc[0].strftime('%B %d, %Y')

# %%
print("Predicted mean of 450 CO2 ppm is to be reached on the date:", high_risk_mean)
print("Predicted lower 95% Confidence Interval of 450 CO2 ppm is to be reached on the date:", high_risk_lower_ci)
print("Predicted upper 95% Confidence Interval of 450 CO2 ppm is to be reached on the date:", high_risk_upper_ci)
# Out:
# Predicted mean of 450 CO2 ppm is to be reached on the date: January 29, 2034
# Predicted lower 95% Confidence Interval of 450 CO2 ppm is to be reached on the date: February 26, 2034
# Predicted upper 95% Confidence Interval of 450 CO2 ppm is to be reached on the date: January 09, 2033

# %%
print("For mean:")
print([round(data_co2_predicted['lower_95_ci'][data_co2_predicted['mean_co2'] >= 450].iloc[0], 3), round(data_co2_predicted['upper_95_ci'][data_co2_predicted['mean_co2'] >= 450].iloc[0], 3)])
# lower CI
print("For lower CI:")
print([round(data_co2_predicted['lower_95_ci'][data_co2_predicted['lower_95_ci'] >= 450].iloc[0], 3), round(data_co2_predicted['upper_95_ci'][data_co2_predicted['lower_95_ci'] >= 450].iloc[0], 3)])
# upper CI
print("For upper CI:")
print([round(data_co2_predicted['lower_95_ci'][data_co2_predicted['upper_95_ci'] >= 450].iloc[0], 3), round(data_co2_predicted['upper_95_ci'][data_co2_predicted['upper_95_ci'] >= 450].iloc[0], 3)])
# Out:
# For mean:
# [449.397, 450.926]
# For lower CI:
# [450.669, 452.388]
# For upper CI:
# [444.498, 451.375]

# %% [markdown]
# ### January 2060

# %%
select_dates = (data_co2_predicted['date'] > '2060-01-01') & (data_co2_predicted['date'] < '2060-01-10')

# %%
print(data_co2_predicted.loc[select_dates])
# Out:
#         Day    mean_co2  lower_95_ci  upper_95_ci       date
# 1996  37163  530.646763   527.403079   532.396047 2060-01-04

# %% [markdown]
# ______
